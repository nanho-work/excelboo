# %%
import pandas as pd
import numpy as np
from PyQt6.QtCharts import QChart, QBarSeries

# %%
pd.set_option('display.max_columns', None)
# 전체민원 시트 불러오기
df = pd.read_excel("/Users/choenamho/Downloads/test.xlsx", sheet_name="전체민원")     
df.head()         # 상위 5개 행 확인
df.columns        # 컬럼명 확인
     # 결측치/데이터 타입 확인
# Out:
# Index(['접수처', '접수일', '처리기한', '처리완료일', '민원유형', 'PG사', '카드사', '승인일', '승인번호',
#        '승인금액', '할부', '가맹점\n사업자번호', '가맹점명', 'MID', 'TID명', 'TID\n사업자번호', '요청사항',
#        '민원인', '민원인 연락처', '민원내용', '처리내용', '처리결과', '취소여부', '취소일자', '입금금액',
#        '입금일자', '입금여부', '요청사항.1', '민원인.1', '처리상태'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# 접수처             0
# 접수일             0
# 처리기한            0
# 처리완료일          50
# 민원유형            0
# PG사             0
# 카드사             0
# 승인일             0
# 승인번호            0
# 승인금액            0
# 할부              0
# 가맹점\n사업자번호      0
# 가맹점명            0
# MID             0
# TID명            0
# TID\n사업자번호      1
# 요청사항          336
# 민원인           375
# 민원인 연락처       380
# 민원내용          387
# 처리내용          368
# 처리결과           50
# 취소여부           50
# 취소일자          171
# 입금금액           37
# 입금일자          265
# 입금여부          171
# 요청사항.1        383
# 민원인.1         293
# 처리상태          178
# dtype: int64

# %%
drop_cols = [
    "요청사항", 
    "민원인", 
    "민원인 연락처", 
    "민원내용", 
    "처리내용", 
    "요청사항.1", 
    "민원인.1",
    "접수처",
    "민원유형",
    "PG사",
    "카드사",
    "승인번호",
    "가맹점\n사업자번호",  # ← 개행문자 포함 주의
    "MID",
    "TID\n사업자번호"      # ← 개행문자 포함 주의
]

df = df.drop(columns=drop_cols)

# %%
df
# Out:
#            접수일       처리기한                처리완료일                  승인일     승인금액  \
# 0   2025-06-25 2025-07-11  2025-07-11 00:00:00           2025-04-03  1392000
# 1   2025-06-25 2025-07-11  2025-07-11 00:00:00           2025-04-03  4356000
# 2   2025-06-25 2025-07-04  2025-07-04 00:00:00           2025-04-03  5000000
# 3   2025-06-25 2025-07-11  2025-07-11 00:00:00           2025-04-03  4752000
# 4   2025-06-25 2025-07-18  2025-07-18 00:00:00           2025-02-13  1000000
# ..         ...        ...                  ...                  ...      ...
# 382 2025-07-31 2025-08-04                  NaN  2024-10-28 00:00:00   990000
# 383 2025-07-31 2025-08-04                  NaN  2025-07-02 00:00:00   850000
# 384 2025-07-31 2025-08-04                  NaN  2024-10-15 00:00:00  2000000
# 385 2025-07-31 2025-08-04                  NaN  2025-07-24 00:00:00  3999000
# 386 2025-07-31 2025-08-04                  NaN  2025-07-24 00:00:00  2999000
#
#      할부              가맹점명          TID명      처리결과  취소여부       취소일자       입금금액  \
# 0     0               피오나  스마트해운항공 주식회사  선취소(미입금)  취소완료 2025-07-11  1338715.0
# 1     0               피오나  스마트해운항공 주식회사  선취소(미입금)  취소완료 2025-07-11  4189253.0
# 2     0               피오나  스마트해운항공 주식회사  선취소(미입금)  취소완료 2025-07-04  4808600.0
# 3     0               피오나  스마트해운항공 주식회사  선취소(미입금)  취소완료 2025-07-11  4570094.0
# 4     0               피오나  스마트해운항공 주식회사  선취소(미입금)  취소완료 2025-07-18   961720.0
# ..   ..               ...           ...       ...   ...        ...        ...
# 382   6  위즈덤인사이트[마이더스플러스]           최한검       NaN   NaN        NaT   902880.0
# 383   0            엠제이컴퍼니       ㈜지앤피홀딩스       NaN   NaN        NaT   816059.0
# 384  12               피오나         ㈜레오나오       NaN   NaN        NaT  1880100.0
# 385   0            153스마트         쇼핑25시       NaN   NaN        NaT  3815046.0
# 386   0            153스마트         쇼핑25시       NaN   NaN        NaT  2861046.0
#
#     입금일자 입금여부 처리상태
# 0    NaT  미입금    Y
# 1    NaT  미입금    Y
# 2    NaT  미입금    Y
# 3    NaT  미입금    Y
# 4    NaT  미입금    Y
# ..   ...  ...  ...
# 382  NaT  NaN  NaN
# 383  NaT  NaN  NaN
# 384  NaT  NaN  NaN
# 385  NaT  NaN  NaN
# 386  NaT  NaN  NaN
#
# [387 rows x 15 columns]

# %%
df.isna().sum()
# Out:
# 접수일        0
# 처리기한       0
# 처리완료일     50
# 승인일        0
# 승인금액       0
# 할부         0
# 가맹점명       0
# TID명       0
# 처리결과      50
# 취소여부      50
# 취소일자     171
# 입금금액      37
# 입금일자     265
# 입금여부     171
# 처리상태     178
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   접수일     387 non-null    datetime64[ns]
#  1   처리기한    387 non-null    datetime64[ns]
#  2   처리완료일   337 non-null    object
#  3   승인일     387 non-null    object
#  4   승인금액    387 non-null    int64
#  5   할부      387 non-null    int64
#  6   가맹점명    387 non-null    object
#  7   TID명    387 non-null    object
#  8   처리결과    337 non-null    object
#  9   취소여부    337 non-null    object
#  10  취소일자    216 non-null    datetime64[ns]
#  11  입금금액    350 non-null    float64
#  12  입금일자    122 non-null    datetime64[ns]
#  13  입금여부    216 non-null    object
#  14  처리상태    209 non-null    object
# dtypes: datetime64[ns](4), float64(1), int64(2), object(8)
# memory usage: 45.5+ KB

# %%
# 접수일 기준으로 '월' 컬럼 생성 (예: 2025-07)
df['접수월'] = df['접수일'].dt.to_period('M').astype(str)

# %%
df['접수월']
# Out:
# 0      2025-06
# 1      2025-06
# 2      2025-06
# 3      2025-06
# 4      2025-06
#         ...
# 382    2025-07
# 383    2025-07
# 384    2025-07
# 385    2025-07
# 386    2025-07
# Name: 접수월, Length: 387, dtype: object

# %%
# 접수일 기준으로 연도와 월 컬럼 분리 생성
df['접수년'] = df['접수일'].dt.year
df['접수월'] = df['접수일'].dt.month

# %%
df['접수년']
# Out:
# 0      2025
# 1      2025
# 2      2025
# 3      2025
# 4      2025
#        ...
# 382    2025
# 383    2025
# 384    2025
# 385    2025
# 386    2025
# Name: 접수년, Length: 387, dtype: int32

# %%
df['접수월']
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 382    7
# 383    7
# 384    7
# 385    7
# 386    7
# Name: 접수월, Length: 387, dtype: int32

# %%
filtered_df = df[(df['접수년'] == 2025) & (df['접수월'] == 7)]

# %%
filtered_df
# Out:
#            접수일       처리기한                처리완료일                  승인일     승인금액  \
# 16  2025-07-01 2025-07-03  2025-07-03 00:00:00  2024-12-16 00:00:00  1000000
# 17  2025-07-01 2025-07-03  2025-07-03 00:00:00  2024-12-10 00:00:00  2897000
# 18  2025-07-01 2025-07-03  2025-07-03 00:00:00  2025-06-25 00:00:00  4000000
# 19  2025-07-01 2025-07-03  2025-07-03 00:00:00  2025-06-25 00:00:00  3000000
# 20  2025-07-01 2025-07-03  2025-07-03 00:00:00  2025-06-25 00:00:00  4700000
# ..         ...        ...                  ...                  ...      ...
# 382 2025-07-31 2025-08-04                  NaN  2024-10-28 00:00:00   990000
# 383 2025-07-31 2025-08-04                  NaN  2025-07-02 00:00:00   850000
# 384 2025-07-31 2025-08-04                  NaN  2024-10-15 00:00:00  2000000
# 385 2025-07-31 2025-08-04                  NaN  2025-07-24 00:00:00  3999000
# 386 2025-07-31 2025-08-04                  NaN  2025-07-24 00:00:00  2999000
#
#      할부              가맹점명           TID명      처리결과  취소여부       취소일자  \
# 16   10               피오나           용마유통  선취소(미입금)  취소완료 2025-07-02
# 17   12    위드페이먼트[153스마트]  주식회사 오앤유페이먼츠2  선취소(미입금)  취소완료 2025-07-02
# 18   12        프리리굿[아르페이]          포텐조명6      매출취소  취소완료 2025-07-02
# 19   12        프리리굿[아르페이]          포텐조명6      매출취소  취소완료 2025-07-02
# 20   12        프리리굿[아르페이]          포텐조명6      매출취소  취소완료 2025-07-02
# ..   ..               ...            ...       ...   ...        ...
# 382   6  위즈덤인사이트[마이더스플러스]            최한검       NaN   NaN        NaT
# 383   0            엠제이컴퍼니        ㈜지앤피홀딩스       NaN   NaN        NaT
# 384  12               피오나          ㈜레오나오       NaN   NaN        NaT
# 385   0            153스마트          쇼핑25시       NaN   NaN        NaT
# 386   0            153스마트          쇼핑25시       NaN   NaN        NaT
#
#           입금금액       입금일자  입금여부 처리상태  접수월   접수년
# 16    954020.0        NaT   미입금    Y    7  2025
# 17   2769532.0        NaT   미입금    Y    7  2025
# 18   3956000.0 2025-07-02  입금완료    Y    7  2025
# 19   2967000.0 2025-07-02  입금완료    Y    7  2025
# 20   4648300.0 2025-07-02  입금완료    Y    7  2025
# ..         ...        ...   ...  ...  ...   ...
# 382   902880.0        NaT   NaN  NaN    7  2025
# 383   816059.0        NaT   NaN  NaN    7  2025
# 384  1880100.0        NaT   NaN  NaN    7  2025
# 385  3815046.0        NaT   NaN  NaN    7  2025
# 386  2861046.0        NaT   NaN  NaN    7  2025
#
# [371 rows x 17 columns]

# %%
# ✅ 월별 가맹점 종합리포트: (가맹점명, TID명) 기준 집계

# 1. 민원발생건수
민원발생건수 = filtered_df.groupby(['가맹점명', 'TID명']).size().reset_index(name='민원발생건수')

# 2. 전체 민원 수
전체민원수 = filtered_df.shape[0]

# 3. 비중(%) 계산
민원발생건수['비중(%)'] = (민원발생건수['민원발생건수'] / 전체민원수 * 100).round(1)

# 4. 처리완료 건수
처리완료_df = filtered_df[filtered_df['처리상태'] == 'Y']
민원처리건수 = 처리완료_df.groupby(['가맹점명', 'TID명']).size().reset_index(name='민원처리건수')

# 5. 결과 병합 및 회신율 계산
결과 = 민원발생건수.merge(민원처리건수, on=['가맹점명', 'TID명'], how='left')
결과['민원처리건수'] = 결과['민원처리건수'].fillna(0).astype(int)
결과['회신율(%)'] = ((결과['민원처리건수'] / 결과['민원발생건수']) * 100).round(1)

# 6. 거래액
거래액 = filtered_df.groupby(['가맹점명', 'TID명'])['승인금액'].sum().reset_index(name='거래액')

# 7. 취소금액
취소금액 = filtered_df.groupby(['가맹점명', 'TID명'])['입금금액'].sum().reset_index(name='취소금액')

# 8. 미수금
미수금_df = filtered_df[filtered_df['입금여부'] == '미입금']
미수금 = 미수금_df.groupby(['가맹점명', 'TID명'])['입금금액'].sum().reset_index(name='미수금')

# 9. 병합 및 취소/미수비율 계산
결과 = 결과.merge(거래액, on=['가맹점명', 'TID명'], how='left')
결과 = 결과.merge(취소금액, on=['가맹점명', 'TID명'], how='left')
결과 = 결과.merge(미수금, on=['가맹점명', 'TID명'], how='left')
결과[['취소금액', '미수금']] = 결과[['취소금액', '미수금']].fillna(0)
결과['취소비율(%)'] = ((결과['취소금액'] / 결과['거래액']) * 100).round(1)
결과['미수비율(%)'] = ((결과['미수금'] / 결과['거래액']) * 100).round(1)

# 10. 평균 객단가
거래건수 = filtered_df.groupby(['가맹점명', 'TID명']).size().reset_index(name='거래건수')
결과 = 결과.merge(거래건수, on=['가맹점명', 'TID명'], how='left')
결과['평균객단가'] = (결과['거래액'] / 결과['거래건수']).round(0).fillna(0).astype(int)

# 11. 평균 할부개월 수
평균할부 = filtered_df.groupby(['가맹점명', 'TID명'])['할부'].mean().reset_index(name='평균할부')
결과 = 결과.merge(평균할부, on=['가맹점명', 'TID명'], how='left')
결과['평균할부'] = 결과['평균할부'].fillna(0).round(1)

# 결과 출력
결과
# Out:
#        가맹점명             TID명  민원발생건수  비중(%)  민원처리건수  회신율(%)       거래액  \
# 0    153스마트              ㈜남명       7    1.9       2    28.6  25320000
# 1    153스마트            ㈜문컴퍼니       6    1.6       0     0.0  24000000
# 2    153스마트  ㈜문컴퍼니 / 뒷돈상회사천점       2    0.5       2   100.0   4200000
# 3    153스마트           ㈜스카이뱅크       4    1.1       1    25.0  13600000
# 4    153스마트          ㈜에스원라이팅       6    1.6       1    16.7  13620000
# ..      ...              ...     ...    ...     ...     ...       ...
# 132     피오나            월드스토어       6    1.6       1    16.7  20000000
# 133     피오나             조이페이       1    0.3       0     0.0    800000
# 134     피오나       주식회사 지엠유통3       1    0.3       1   100.0   1500000
# 135     피오나        티디엔(순페이x)       2    0.5       0     0.0   3210000
# 136     피오나       파머스상회 서초지점       2    0.5       2   100.0   8900000
#
#            취소금액        미수금  취소비율(%)  미수비율(%)  거래건수    평균객단가  평균할부
# 0    24205920.0  4780000.0     95.6     18.9     7  3617143  17.1
# 1    22944000.0        0.0     95.6      0.0     6  4000000  10.0
# 2           0.0        0.0      0.0      0.0     2  2100000   5.0
# 3    13001600.0        0.0     95.6      0.0     4  3400000   6.0
# 4    13020720.0        0.0     95.6      0.0     6  2270000  10.0
# ..          ...        ...      ...      ...   ...      ...   ...
# 132  16235170.0        0.0     81.2      0.0     6  3333333   4.3
# 133    769200.0        0.0     96.2      0.0     1   800000   3.0
# 134   1450500.0        0.0     96.7      0.0     1  1500000   7.0
# 135   3157035.0        0.0     98.4      0.0     2  1605000   0.0
# 136   8312600.0        0.0     93.4      0.0     2  4450000   5.0
#
# [137 rows x 14 columns]
